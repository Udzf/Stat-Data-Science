# %% [markdown]
# <a href="https://colab.research.google.com/github/gaojing33/Stat-Data-Science/blob/main/average%20waste%20and%20income.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# !pip install openpyxl

# %%
import pandas as pd

file_path = '/content/cleanedGeneva.xlsx'
df = pd.read_excel(file_path)

df.head()
# Out:
#             city  year  totalwaste  population  grossincom  averagewaste
# 0  Aire-la-Ville  2003      232.00         736    102310.0      0.315217
# 1  Aire-la-Ville  2004      206.40         727     96923.0      0.283906
# 2  Aire-la-Ville  2005      204.20         836    107811.0      0.244258
# 3  Aire-la-Ville  2006      222.00         909    109556.0      0.244224
# 4  Aire-la-Ville  2007      244.03        1095    112947.0      0.222858

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# 1. Load the data (xlsx format)
file_path = '/content/cleanedGeneva.xlsx'  # Ensure the path is correct
df = pd.read_excel(file_path)

# 2. Select the required columns
X = df[['grossincom']]  # Independent variable
y = df['averagewaste']  # Dependent variable

# 3. Fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# 4. Make predictions
y_pred = model.predict(X)

# 5. Print the regression coefficient and intercept
print(f"Regression Coefficient: {model.coef_[0]}")
print(f"Intercept: {model.intercept_}")

# 6. Calculate MSE and R²
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R²): {r2}")

# 7. Visualize the results
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['grossincom'], y=df['averagewaste'], color='blue', label='Actual values')
plt.plot(df['grossincom'], y_pred, color='red', label='Regression Line')
plt.title('Average Waste vs Gross Income')
plt.xlabel('Gross Income')
plt.ylabel('Average Waste')
plt.legend()
plt.show()
# Out:
# Regression Coefficient: -2.967371423057802e-07
# Intercept: 0.28853520138005473
# Mean Squared Error (MSE): 0.002238701774398636
# R-squared (R²): 0.00858367324866982
